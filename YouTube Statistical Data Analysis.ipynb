# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

# Configure libraries
# The seaborn library makes plots look nicer
sns.set()
sns.set_context('talk')

pd.options.display.max_rows = 500
pd.options.display.max_columns = 20

# %%
YT_Trailers = pd.read_csv('USvideos.csv')
df_movies = pd.read_csv('movie_metadata.csv')

print(YT_Trailers)
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
#Creating a subset with trending videoes that only include IMDB movie title
##YT_TrailersF = YT_Trailers.drop(YT_Trailers[YT_Trailers.category_id != 1].index, inplace=True)

#Dropping all entries that does not contain Trailer in the tags column
#YT_Trailers.drop(YT_Trailers[~YT_Trailers.tags.str.contains("Trailer", case=False)].index, inplace=True)

#Dropping all entries that does not contains Trailer in the title column 
YT_Trailers.drop(YT_Trailers[~YT_Trailers.title.str.contains("Trailer", case=False)].index, inplace=True)

#Dropping all entries that contains Honest in the title column to filter out all "Honest Trailer" videos
YT_Trailers.drop(YT_Trailers[YT_Trailers.title.str.contains("Honest Trailer", case=False)].index, inplace=True)

#Dropping all entries that does not contains Movie in the tags column
#YT_Trailers.drop(YT_Trailers[~YT_Trailers.tags.str.contains("Movie", case=False)].index, inplace=True)

YT_Trailers.sort_values(by=['title'], inplace=True)

sum(df_movies.movie_title.isnull())

##print(YT_Trailers)
# Out:
# 0

# %%
df = pd.DataFrame(columns=['video_id', 'trending_date', 'title', 'channel_title', 'category_id', 'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count', 'thumbnail_link', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed', 'description'])


df.append(YT_Trailers[YT_Trailers.title.str.contains("Avatar",case=False, regex=False)], ignore_index=True)
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description]
# Index: []

# %%
df.equals(YT_Trailers)
# Out:
# False
